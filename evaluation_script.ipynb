# %%
import pickle
PATH = '/om2/user/shania/protein_func_new'

heal_dicts = [
    'heal_output_dict_train_bp_baseline_bp.pkl',
    'heal_output_dict_train_cc_baseline_cc.pkl',
    'heal_output_dict_train_mf_baseline_mf.pkl',
]

heal_cl_dicts = [
    'heal_output_dict_train_bp_baseline_bpCL.pkl',
    'heal_output_dict_train_cc_baseline_ccCL.pkl',
    'heal_output_dict_train_mf_baseline_mfCL.pkl',
]


sfnet_cl_dicts = [
    'grpn_output_dict_train_bp_sfnet_HD_bpCL2.pkl',
    'grpn_output_dict_train_cc_sfnet_HD_ccCL2.pkl',
    'grpn_output_dict_train_mf_sfnet_HD_mfCL2.pkl'
]

sfnet_dicts = [
    'grpn_output_dict_train_bp_sfnet_HD_bp2_noss.pkl',
    'grpn_output_dict_train_cc_sfnet_HD_cc2_noss.pkl',
    'grpn_output_dict_train_mf_sfnet_HD_mf2_noss.pkl'
]

num = 2
# option = sfnet_cl_dicts[num]
option = sfnet_dicts[num]
# option = heal_dicts[num]
# option = heal_cl_dicts[num]

d = pickle.load(open(f'../output_dicts/{option}', 'rb'))
# d = pickle.load(open(f'{PATH}/output_dicts/grpn_output_dict_train_bp_new_grpn_test.pkl', 'rb'))
bp = 1943
cc = 320
mf = 489

shape = [bp, cc, mf]

d['Y_true'] = d['Y_true'].reshape(-1, shape[num])
d['Y_pred'] = d['Y_pred'].reshape(-1, shape[num])
f = open(f'{PATH}/output_dicts/temp.pkl', 'wb')
pickle.dump(d, f)
f.close()
d = pickle.load(open(f'../output_dicts/temp.pkl', 'rb'))

from evaluation_metrics import Metrics
# met = Metrics('', '../output_dicts/grpn_output_dict_train_bp.pkl')
met = Metrics('', f'../output_dicts/temp.pkl')
# met = Metrics('', 'output_dictbp.pkl')
fmax = met.fmax(keep_pidx=None)
aupr = met.macro_aupr(keep_pidx=None)
smin = met.smin(keep_pidx=None)

print("/n/n/n/n=========================")
print("FMAX   |   AUPR   |   SMIN")
print("{:.4f} | {:.4f} | {:.4f}".format(fmax, aupr, smin))
# Out:
# Inside fmax
# Inside protein centric fmax ont
# Inside cafa go aupr n 3414
# 0/3413
# 1/3413
# 2/3413
# 3/3413
# 4/3413
# 5/3413
# 6/3413
# 7/3413
# 8/3413
# 9/3413
# 10/3413
# 11/3413
# 12/3413
# 13/3413
# 14/3413
# 15/3413
# 16/3413
# 17/3413
# 18/3413
# 19/3413
# 20/3413
# 21/3413
# 22/3413
# 23/3413
# 24/3413
# 25/3413
# 26/3413
# 27/3413
# 28/3413
# 29/3413
# 30/3413
# 31/3413
# 32/3413
# 33/3413
# 34/3413
# 35/3413
# 36/3413
# 37/3413
# 38/3413
# 39/3413
# 40/3413
# 41/3413
# 42/3413
# 43/3413
# 44/3413
# 45/3413
# 46/3413
# 47/3413
# 48/3413
# 49/3413
# 50/3413
# 51/3413
# 52/3413
# 53/3413
# 54/3413
# 55/3413
# 56/3413
# 57/3413
# 58/3413
# 59/3413
# 60/3413
# 61/3413
# 62/3413
# 63/3413
# 64/3413
# 65/3413
# 66/3413
# 67/3413
# 68/3413
# 69/3413
# 70/3413
# 71/3413
# 72/3413
# 73/3413
# 74/3413
# 75/3413
# 76/3413
# 77/3413
# 78/3413
# 79/3413
# 80/3413
# 81/3413
# 82/3413
# 83/3413
# 84/3413
# 85/3413
# 86/3413
# 87/3413
# 88/3413
# 89/3413
# 90/3413
# 91/3413
# 92/3413
# ...

# %%
import torch
x = torch.randn(3)
torch.cat((x,x))
# Out:
# tensor([-1.9833, -0.3382, -0.5794, -1.9833, -0.3382, -0.5794])

# %%
import torch
pdbsite = torch.load('/om2/user/shania/datasets/pdbsite_data_list.pt')
pdbsite
# Out:
# /om2/user/shania/anaconda/envs/esm_fold/lib/python3.9/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# [Data(x=[630, 1280], edge_index=[2, 4694], y=[630], subtype=[630], pdbsiteid=[630], lensite=[630], coords=[630, 3], ego_label=[630], weight=[4694]),
#  Data(x=[618, 1280], edge_index=[2, 4382], y=[618], subtype=[618], pdbsiteid=[618], lensite=[618], coords=[618, 3], ego_label=[618], weight=[4382]),
#  Data(x=[300, 1280], edge_index=[2, 2098], y=[300], subtype=[300], pdbsiteid=[300], lensite=[300], coords=[300, 3], ego_label=[300], weight=[2098]),
#  Data(x=[337, 1280], edge_index=[2, 2370], y=[337], subtype=[337], pdbsiteid=[337], lensite=[337], coords=[337, 3], ego_label=[337], weight=[2370]),
# ...

# %%
# Out:
# ['None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
# ...
